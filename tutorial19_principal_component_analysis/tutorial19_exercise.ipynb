# %% [markdown]
# #### Tutorial 19 exercise

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('tutorial19_heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.shape
# Out:
# (918, 12)

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df2 = df

# %%
df2
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df
# Out:
#      Age  Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40    1           ATA        140          289          0     Normal
# 1     49    0           NAP        160          180          0     Normal
# 2     37    1           ATA        130          283          0         ST
# 3     48    0           ASY        138          214          0     Normal
# 4     54    1           NAP        150          195          0     Normal
# ..   ...  ...           ...        ...          ...        ...        ...
# 913   45    1            TA        110          264          0     Normal
# 914   68    1           ASY        144          193          1     Normal
# 915   57    1           ASY        130          131          0     Normal
# 916   57    0           ATA        130          236          0        LVH
# 917   38    1           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df['ChestPainType'] = le.fit_transform(df['ChestPainType'])

# %%
df['RestingECG'] = le.fit_transform(df['RestingECG'])

# %%
df['ExerciseAngina'] = le.fit_transform(df['ExerciseAngina'])

# %%
df['ST_Slope'] = le.fit_transform(df['ST_Slope'])

# %%
df
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...

# %%
X = df.drop('HeartDisease', axis='columns')

# %%
y = df['HeartDisease']

# %%
X
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
#      MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.4331398 ,  0.51595242,  0.22903206, ..., -0.8235563 ,
#         -0.83243239,  1.05211381],
#        [-0.47848359, -1.93816322,  1.27505906, ..., -0.8235563 ,
#          0.10566353, -0.59607813],
#        [-1.75135854,  0.51595242,  0.22903206, ..., -0.8235563 ,
#         -0.83243239,  1.05211381],
#        ...,
#        [ 0.37009972,  0.51595242, -0.81699495, ...,  1.21424608,
#          0.29328271, -0.59607813],
#        [ 0.37009972, -1.93816322,  0.22903206, ..., -0.8235563 ,
#         -0.83243239, -0.59607813],
#        [-1.64528563,  0.51595242,  1.27505906, ..., -0.8235563 ,
#         -0.83243239,  1.05211381]], shape=(918, 11))

# %%
from sklearn.model_selection import train_test_split
Xs_train, Xs_test, ys_train, ys_test = train_test_split(X_scaled, y, test_size=0.3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.svm import SVC
model1 = SVC()

# %%
model1.fit(Xs_train, ys_train)
# Out:
# SVC()

# %%
model1.score(Xs_test, ys_test)
# Out:
# 0.8623188405797102

# %%
model2 = SVC()
model2.fit(X_train, y_train)
model2.score(X_test, y_test)
# Out:
# 0.7137681159420289

# %%
from sklearn.linear_model import LogisticRegression
model3 = LogisticRegression()
model3.fit(Xs_train, ys_train)
model3.score(Xs_test, ys_test)
# Out:
# 0.8478260869565217

# %%
from sklearn.ensemble import RandomForestClassifier
model4 = RandomForestClassifier()
model4.fit(Xs_train, ys_train)
model4.score(Xs_test, ys_test)
# Out:
# 0.8586956521739131

# %%
from sklearn.decomposition import PCA
pca1 = PCA(0.95)    # This is 95%. For achivel 95%, it takes that many pipelines

# %%
pca1_data = pca1.fit_transform(X_scaled)

# %%
pca1_data.shape
# Out:
# (918, 10)

# %%
pca1.explained_variance_ratio_
# Out:
# array([0.25139665, 0.1330889 , 0.10512913, 0.09088956, 0.07916761,
#        0.07695206, 0.07333057, 0.05675535, 0.05066628, 0.04557194])

# %%
Xp_train, Xp_test, yp_train, yp_test = train_test_split(pca1_data, y, test_size=0.3)

# %%
model6 = SVC()
model6.fit(Xp_train, yp_train)
model6.score(Xp_test, yp_test)
# Out:
# 0.855072463768116

# %%
model7 = LogisticRegression()
model7.fit(Xp_train, yp_train)
model7.score(Xp_test, yp_test)
# Out:
# 0.8297101449275363

# %%
model8 = RandomForestClassifier()
model8.fit(Xp_train, yp_train)
model8.score(Xp_test, yp_test)
# Out:
# 0.8369565217391305

# %%
pca2 = PCA(n_components=7)    # We have given to consider only 6 columns

# %%
pca2_data = pca2.fit_transform(X)

# %%
pca2_data.shape
# Out:
# (918, 7)

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(pca2_data, y, test_size=0.3)

# %%
model11 = SVC()
model11.fit(X2_train, y2_train)
model11.score(X2_test, y2_test)
# Out:
# 0.7282608695652174

# %%
model12 = LogisticRegression()
model12.fit(X2_train, y2_train)
model12.score(X2_test, y2_test)
# Out:
# 0.7862318840579711

# %%
model12 = RandomForestClassifier()
model12.fit(X2_train, y2_train)
model12.score(X2_test, y2_test)
# Out:
# 0.7971014492753623

# %% [markdown]
# ##### Ww can see the score is decreasing when we reduce the columns
