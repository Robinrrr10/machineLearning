# %% [markdown]
# ### Tutorial 10 : Support Vector Machine (SVM)

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target
# 0                  5.1               3.5                1.4               0.2       0
# 1                  4.9               3.0                1.4               0.2       0
# 2                  4.7               3.2                1.3               0.2       0
# 3                  4.6               3.1                1.5               0.2       0
# 4                  5.0               3.6                1.4               0.2       0
# ..                 ...               ...                ...               ...     ...
# 145                6.7               3.0                5.2               2.3       2
# 146                6.3               2.5                5.0               1.9       2
# 147                6.5               3.0                5.2               2.0       2
# 148                6.2               3.4                5.4               2.3       2
# ...

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['target_names'] = df.target.apply(lambda x : iris.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target target_names
# 0                  5.1               3.5                1.4               0.2       0       setosa
# 1                  4.9               3.0                1.4               0.2       0       setosa
# 2                  4.7               3.2                1.3               0.2       0       setosa
# 3                  4.6               3.1                1.5               0.2       0       setosa
# 4                  5.0               3.6                1.4               0.2       0       setosa
# ..                 ...               ...                ...               ...     ...          ...
# 145                6.7               3.0                5.2               2.3       2    virginica
# 146                6.3               2.5                5.0               1.9       2    virginica
# ...

# %%
df[df.target==0].shape
# Out:
# (50, 6)

# %%
df[df.target==0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target target_names
# 0                5.1               3.5                1.4               0.2       0       setosa
# 1                4.9               3.0                1.4               0.2       0       setosa
# 2                4.7               3.2                1.3               0.2       0       setosa
# 3                4.6               3.1                1.5               0.2       0       setosa
# 4                5.0               3.6                1.4               0.2       0       setosa

# %%
df[df.target==1].shape
# Out:
# (50, 6)

# %%
df[df.target==1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target target_names
# 50                7.0               3.2                4.7               1.4       1   versicolor
# 51                6.4               3.2                4.5               1.5       1   versicolor
# 52                6.9               3.1                4.9               1.5       1   versicolor
# 53                5.5               2.3                4.0               1.3       1   versicolor
# 54                6.5               2.8                4.6               1.5       1   versicolor

# %%
df[df.target == 2].shape
# Out:
# (50, 6)

# %%
df[df.target==2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target target_names
# 100                6.3               3.3                6.0               2.5       2    virginica
# 101                5.8               2.7                5.1               1.9       2    virginica
# 102                7.1               3.0                5.9               2.1       2    virginica
# 103                6.3               2.9                5.6               1.8       2    virginica
# 104                6.5               3.0                5.8               2.2       2    virginica

# %%
df0 = df[df.target==0]
df1 = df[df.target==1]
df2 = df[df.target==2]

# %%
df0.shape
# Out:
# (50, 6)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color='green', marker='+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'], color='blue', marker='+')

# %%
plt.xlabel('petal length (cm)')
plt.ylabel('petal width (cm)')
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'], color='brown', marker='.')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'], color='red', marker='.')

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target target_names
# 0                5.1               3.5                1.4               0.2       0       setosa
# 1                4.9               3.0                1.4               0.2       0       setosa
# 2                4.7               3.2                1.3               0.2       0       setosa
# 3                4.6               3.1                1.5               0.2       0       setosa
# 4                5.0               3.6                1.4               0.2       0       setosa

# %%
X = df.drop(['target', 'target_names'], axis='columns')

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y = df.target
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# #### We can pass the above parameter to optimize

# %%
model.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# ### Below we can change the parameter and see the result. This is just to see

# %%
model = SVC(C=10)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model = SVC(gamma=5)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
model = SVC(kernel='linear')
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 1.0

# %%
model = SVC(C = 10, kernel = 'linear')
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# #### We can see the score changes when optimize using the params.
# #### Now we can use predict for highest score and it will predict fine
